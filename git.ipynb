# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pwd && ls -al

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/drive/My Drive/Colab Notebooks/인공지능_비트_트레이더_경진대회_시즌2/.git/

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/인공지능_비트_트레이더_경진대회_시즌2
#!git init
# !git config --global user.email "fromptj@gmail.com"
# !git config --global user.name "fromptj"
# Out:
# /content/drive/MyDrive/Colab Notebooks/인공지능_비트_트레이더_경진대회_시즌2

# %%
# !git remote add origin https://fromptj:tlgja147@github.com/fromptj/Bitcoin-Trader-Contest-Season2.git

# %%
# !git remote rm origin

# %%
# !git add .
# !git commit -m "인공지능 비트 트레이더 경진대회 모델 정리"
# !git push origin master
# Out:
# On branch master
# nothing to commit, working tree clean
# Counting objects: 8, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 48.64 KiB | 5.40 MiB/s, done.
# Total 8 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/fromptj/Bitcoin-Trader-Contest-Season2.git
#  * [new branch]      master -> master
