# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pwd && ls -al
# Out:
# /content/drive/My Drive/Colab Notebooks/인공지능_비트_트레이더_경진대회_시즌2
# total 97
# -rw------- 1 root root 89817 Jun  8 13:59 CNN_2d_conv_model
# drwx------ 8 root root  4096 Aug  6 08:23 .git
# -rw------- 1 root root   159 Aug  6 08:22 .gitignore
# -rw------- 1 root root  3906 Aug  6 08:23 git.ipynb

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/인공지능_비트_트레이더_경진대회_시즌2
#!git init
# !git config --global user.email "fromptj@gmail.com"
# !git config --global user.name "fromptj"
# Out:
# /content/drive/MyDrive/Colab Notebooks/인공지능_비트_트레이더_경진대회_시즌2

# %%
# !git remote add origin https://fromptj:tlgja147@github.com/fromptj/Bitcoin-Trader-Contest-Season2.git

# %%
# !git remote rm origin

# %%
# !git add .
# !git commit -m "gitignore 정리"
# !git push origin master
# Out:
# [master 723c1ab] gitignore 정리
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 1.21 KiB | 621.00 KiB/s, done.
# Total 6 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 2 local objects.
# To https://github.com/fromptj/Bitcoin-Trader-Contest-Season2.git
#    b206a0c..723c1ab  master -> master
